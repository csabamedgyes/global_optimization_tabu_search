# %% [markdown]
# Üdv! Ez a Notebook Medgyes Csaba (RF8I8P) és Mészáros Bálint (HY90XY) projektmunkája a Globális Optimalizálás második részére. A projekt során az információt az alábbi forrásokból szereztük:
#
# - https://medium.com/swlh/tabu-search-in-python-3199c44d44f1
#
# - https://leeds-faculty.colorado.edu/glover/227%20-%20A%20Users%20Guide%20to%20Tabu%20Search%20-%20conversion%203%2026%2014.pdf
#
# Mivel a Medium cikkben gyakorlatilag tökéletesen összefoglalták a módszert, így ezt szeretnénk demonstrálni, a végén három példával.

# %% [markdown]
# ## Bevezetés

# %% [markdown]
# Szeretnénk betekintést tekinteni hogyan működik a TS módszer az NP nehéz Single Machine Total Weighted Tardiness Problem megoldásával.
#
# **The Single Machine Total Weighted Tardiness Problem**: Van egy gépünk mely egyszerre egy feladatot tud megoldani. Összesen $N$ feladat van melyeket megszakítás nélkül szeretnénk megoldani. Minden $i \in N$ feladatnak $P_i$ egész feldolgozási időre van szüksége, és pozitív súlya $W_i$ jelzi a feladat fontosságát és $d_i$ jelzi az esedékességét. Ha feltesszük, hogy a gép azonnal munkába áll, akkor az $i$ feladat befejezési idejét $C_i$-vel jelöljük, a munka késését pedig $T_i = max\{C_i − d_i, 0\}$ értékkel számíthatjuk ki. Ha a feladat feldolgozása a $C_i \leq d_i$ esedékessége előtt megtörténik, akkor nem lesz késés, tehát $T = 0$. A cél az, hogy a $N$ feladatokat úgy rendezzük, hogy minimálisra csökkenjen a teljes folyamat súlyozott késése, azaz $\min \sum W_i T_i$. Figyeljük meg, hogy ha egy munka nagyobb súlyú, a késés miatti büntetés magasabb lesz.

# %% [markdown]
# ## Tabu Search

# %% [markdown]
# Először importáljuk a szükséges csomagokat:

# %%
import pandas as pd
import random as rd
from itertools import combinations
import math

# %% [markdown]
# Vegyük a következő példát és kezdjük a TS elméletével. Az alábbi módon van megadva az adatunk:

# %%
pd.read_excel('Instance_10.xlsx', names=['Job', 'weight', "processing_time", "due_date"],index_col=0).to_dict('index')
# Out:
# {1: {'weight': 0.5, 'processing_time': 1.5, 'due_date': 4},
#  2: {'weight': 0.8, 'processing_time': 2.2, 'due_date': 4},
#  3: {'weight': 0.6, 'processing_time': 0.5, 'due_date': 4},
#  4: {'weight': 0.4, 'processing_time': 1.6, 'due_date': 6},
#  5: {'weight': 0.4, 'processing_time': 3.5, 'due_date': 6},
#  6: {'weight': 0.1, 'processing_time': 2.1, 'due_date': 6},
#  7: {'weight': 0.2, 'processing_time': 2.5, 'due_date': 8},
#  8: {'weight': 0.5, 'processing_time': 0.6, 'due_date': 8},
#  9: {'weight': 0.3, 'processing_time': 3.2, 'due_date': 8},
#  10: {'weight': 0.6, 'processing_time': 5.2, 'due_date': 8}}

# %% [markdown]
# Az optimalizálni kívánt célfüggvény $\min \sum W_i T_i$, melynek értéke az adott megoldás alkalmasságát jelöli. Most foglaljuk össze az algoritmust.

# %% [markdown]
# **Tabu Search Basic Algorithm**: A TS minden iterációban megpróbálja megtalálni a legjobb elfogadható megoldást az aktuális megoldás közelében, a legújabb megoldásokat „Tabu”-nak tekintve a ciklikusság megelőzésére. Kezdjük az algoritmus általános lépéseivel:

# %% [markdown]
# - **0. Lépés**: Egy kezdőmegoldás létrehozása. Ez az algoritmus kezdőpontja, gyakran randomizált.

# %% [markdown]
# - **1. lépés**: Tekintve, hogy megvan a kezdeti megoldás, a következő lépés az, hogy a jelenlegi $\mathbb{S}$ (jelen esetben a 0. iteráció kezdeti megoldása) megoldásból létrehozzuk a lehetséges megoldások listáját. Ezeket a megoldásokat hívjuk  $\mathbb{S}$ szomszédainak. Ahhoz, hogy a jelenlegi $\mathbb{S}$ megoldásból megtaláljuk a szomszédos megoldásokat, meg kell határoznunk a szomszédsági függvényt, amely minden $\matbb{S}$ megoldáshoz rendel egy megoldások részhalmazát.
#
# Megjegyzés: Tegyük fel, hogy az SMTWTP jelenlegi megoldása $\mathbb{S}$ = [3, 8, 10, 4, 1, 6, 2, 5, 9, 7], és a szomszédsági függvény a swap, mely két feladat sorendjét cseréli ki. Ekkor az egyik szomszédsági megoldás a [8, 3, 10, 4, 1, 6, 2, 5, 9, 7] lenne. Ez $O(n^2)$, mivel $(n-2)$ szomszédja van az $n$ feladatból álló megoldásnak.

# %% [markdown]
# - **2. lépés**: Az első lépésben létrehozott szomszédsági listából válasszuk ki a legjobb nem-tabu vagy aspirációs kritériumnak megfelelő megoldást (lásd Diagram):

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(url="tabuabra.jpg", width=400, height=400)
# Out:
# <img src="tabuabra.jpg" width="400" height="400"/>

# %% [markdown]
# *Tabu List*: Ez az a lista, amellyel a TS rögzíti a legújabb megoldásokat, és bizonyos számú iterációig megakadályozza azok ismétlődését, ami segít a keresésnek eltávolodni a korábban látogatott megoldásoktól.

# %% [markdown]
# *Tabu Tenure*: Ez határozza meg a Tabu-lista méretét, vagyis azt, hogy hány iterációra maradjon meg egy megoldás-összetevő Tabuként.
#
# Megyjegzés: problémánkban feltehetjük, hogy a Tabu Tenure 2, ekkor az első iterációban a Tabu List üres. Tegyük fel, hogy az első iterációban talált megengedett megoldás: [8, 3, 5, 4, 1, 6, 2, 10, 9, 7]. Ekkor a Tabu List:  {[8, 3, 5, 4, 1, 6, 2, 10, 9, 7]}, a második iterációban talált optimális megoldást még mindig: [8, 3, 5, 4, 1, 6, 2, 10, 9, 7], azonban ez nem megengedett, mert Tabu, szóval vesszük a következő legjobbat. Tegyük fel hogy ez: [8, 3, 5, 4, 1, 6, 2, 10, 7,9], ekkor a Tabu List: {[8, 3, 5, 4, 1, 6, 2, 10, 9, 7], [8, 3, 5, 4, 1, 6, 2, 10, 7,9]}. A harmadk iterációban [8, 3, 5, 4, 1, 6, 2, 10, 9, 7] megoldás elhagyja a Tabu listát, és a legjobb megengedett megoldás kerül a listába. Fontos megjegyzés, hogy minél kisebb a Tabu Tenure annál nagyobb a valószínűsége, hogy ciklikusság alakul ki.

# %% [markdown]
# *Tabu Attribute*: Ha nagy a probléma ($n$ száma magas) és a Tabu Tenure is magas, akkor érdmesebb a cseréket számon tartani, nem a teljes megoldásokat. Az előző példával élve, eltárolatjuk a cserélt munkákat, tehát a Tabu List {(8,3), (7,9)} alakú.

# %% [markdown]
# *Aspiration Criteria*: Ha az aktuális iterációban talált megoldás célfüggvény-értéke jobb, mint a jelenleg ismert legjobb megoldás értéke, de a lépés Tabu, akkor az Aspirációs Kritérium felülírja ennek a lépésnek Tabu állapotát, ezáltal az egyébként kizárt megoldásokat is belefoglalja az engedélyezett megoldások halmazába.

# %% [markdown]
# - **3. lépés**: Ellenőrizze a definiált leállítási feltételeket: ez lehet az elért iterációk maximális száma vagy a futás ideje. Ha a leállítási feltételek nem teljesülnek, menjen a 4. lépésre, ha a leállítási feltételek teljesülnek, fejezze be és adja vissza a legjobb megoldást.

# %% [markdown]
# - **4. lépés**: Frissítsük a Tabu listát, az aspirációs kritériumot és menjünk vissza az 1. lépésre.

# %% [markdown]
# ### TS objektum kódja:

# %% [markdown]
# A következő TS osztály nagyjából ugyanaz mint a cikkben, azonban kommentekkel szeretnénk segíteni a megértést.

# %%
class TS():
    
    def __init__(self, Path, seed, tabu_tenure):
        
        self.Path = Path
        self.seed = seed
        self.tabu_tenure = tabu_tenure
        self.instance_dict = self.input_data()
        self.Initial_solution = self.get_InitialSolution()
        self.tabu_str, self.Best_solution, self.Best_objvalue = self.TSearch()
        
    def input_data(self):
        
        return pd.read_excel(self.Path, names=['Job', 'weight', "processing_time", "due_date"], index_col=0).to_dict('index')

    def get_tabuestructure(self):
        '''Takes a dict (input data)
        Returns a dict of tabu attributes(pair of jobs that are swapped) as keys and [tabu_time, MoveValue]
        '''
        dict = {}
        for swap in combinations(self.instance_dict.keys(), 2):
            dict[swap] = {'tabu_time': 0, 'MoveValue': 0}
        return dict

    def get_InitialSolution(self, show=False):
        n_jobs = len(self.instance_dict) # Number of jobs
        # Producing a random schedule of jobs
        initial_solution = list(range(1, n_jobs+1))
        rd.seed(self.seed)
        rd.shuffle(initial_solution)
        if show == True:
            print("initial Random Solution: {}".format(initial_solution))
        return initial_solution

    def Objfun(self, solution, show = False):
        '''Takes a set of scheduled jobs, dict (input data)
        Return the objective function value of the solution
        '''
        dict = self.instance_dict
        t = 0   #starting time
        objfun_value = 0
        for job in solution:
            C_i = t + dict[job]["processing_time"]  # Completion time
            d_i = dict[job]["due_date"]   # due date of the job
            T_i = max(0, C_i - d_i)    #tardiness for the job
            W_i = dict[job]["weight"]  # job's weight

            objfun_value +=  W_i * T_i
            t = C_i
        if show == True:
            print("\n","#"*8, "The Objective function value for {} solution schedule is: {}".format(solution ,objfun_value),"#"*8)
        return objfun_value

    def SwapMove(self, solution, i ,j):
        '''Takes a list (solution)
        returns a new neighbor solution with i, j swapped
       '''
        solution = solution.copy()
        # job index in the solution:
        i_index = solution.index(i)
        j_index = solution.index(j)
        #Swap
        solution[i_index], solution[j_index] = solution[j_index], solution[i_index]
        return solution

    def TSearch(self):
        '''The implementation Tabu search algorithm with short-term memory and pair_swap as Tabu attribute.
        '''
        # Parameters:
        tenure =self.tabu_tenure
        tabu_structure = self.get_tabuestructure()  # Initialize the data structures
        best_solution = self.Initial_solution
        best_objvalue = self.Objfun(best_solution)
        current_solution = self.Initial_solution
        current_objvalue = self.Objfun(current_solution)

        print("#"*30, "Short-term memory TS with Tabu Tenure: {}\nInitial Solution: {}, Initial Objvalue: {}".format(
            tenure, current_solution, current_objvalue), "#"*30, sep='\n\n')
        iter = 1
        Terminate = 0
        while Terminate < 100:
            print('\n\n### iter {}###  Current_Objvalue: {}, Best_Objvalue: {}'.format(iter, current_objvalue,
                                                                                    best_objvalue))
            # Searching the whole neighborhood of the current solution:
            for move in tabu_structure:
                candidate_solution = self.SwapMove(current_solution, move[0], move[1])
                candidate_objvalue = self.Objfun(candidate_solution)
                tabu_structure[move]['MoveValue'] = candidate_objvalue

            # Admissible move
            while True:
                # select the move with the lowest ObjValue in the neighborhood (minimization)
                best_move = min(tabu_structure, key =lambda x: tabu_structure[x]['MoveValue'])
                MoveValue = tabu_structure[best_move]["MoveValue"]
                tabu_time = tabu_structure[best_move]["tabu_time"]
                # Not Tabu
                if tabu_time < iter:
                    # make the move
                    current_solution = self.SwapMove(current_solution, best_move[0], best_move[1])
                    current_objvalue = self.Objfun(current_solution)
                    # Best Improving move
                    if MoveValue < best_objvalue:
                        best_solution = current_solution
                        best_objvalue = current_objvalue
                        print("   best_move: {}, Objvalue: {} => Best Improving => Admissible".format(best_move,
                                                                                                      current_objvalue))
                        Terminate = 0
                    else:
                        print("   ##Termination: {}## best_move: {}, Objvalue: {} => Least non-improving => "
                              "Admissible".format(Terminate,best_move,
                                                                                                           current_objvalue))
                        Terminate += 1
                    # update tabu_time for the move
                    tabu_structure[best_move]['tabu_time'] = iter + tenure
                    iter += 1
                    break
                # If tabu
                else:
                    # Aspiration
                    if MoveValue < best_objvalue:
                        # make the move
                        current_solution = self.SwapMove(current_solution, best_move[0], best_move[1])
                        current_objvalue = self.Objfun(current_solution)
                        best_solution = current_solution
                        best_objvalue = current_objvalue
                        print("   best_move: {}, Objvalue: {} => Aspiration => Admissible".format(best_move,
                                                                                                      current_objvalue))
                        Terminate = 0
                        iter += 1
                        break
                    else:
                        tabu_structure[best_move]["MoveValue"] = float('inf')
                        print("   best_move: {}, Objvalue: {} => Tabu => Inadmissible".format(best_move,
                                                                                              current_objvalue))
                        continue
        print('#'*50 , "Performed iterations: {}".format(iter), "Best found Solution: {} , Objvalue: {}".format(best_solution,best_objvalue), sep="\n")
        return tabu_structure, best_solution, best_objvalue

# %% [markdown]
# ## Első teszt :

# %% [markdown]
# Az adatunk az alábbi:

# %%
pd.read_excel('Instance_10.xlsx', names=['Job', 'weight', "processing_time", "due_date"], index_col=0)
# Out:
#      weight  processing_time  due_date
# Job
# 1       0.5              1.5         4
# 2       0.8              2.2         4
# 3       0.6              0.5         4
# 4       0.4              1.6         6
# 5       0.4              3.5         6
# 6       0.1              2.1         6
# 7       0.2              2.5         8
# 8       0.5              0.6         8
# 9       0.3              3.2         8
# 10      0.6              5.2         8

# %% [markdown]
# Ekkor tesztelve a fentebbieket:

# %%
test = TS(Path="Instance_10.xlsx", seed = 2012, tabu_tenure=3)
# Out:
# ##############################
#
# Short-term memory TS with Tabu Tenure: 3
# Initial Solution: [4, 7, 9, 1, 5, 3, 10, 6, 8, 2], Initial Objvalue: 39.080000000000005
#
# ##############################
#
#
# ### iter 1###  Current_Objvalue: 39.080000000000005, Best_Objvalue: 39.080000000000005
#    best_move: (2, 7), Objvalue: 26.13 => Best Improving => Admissible
#
#
# ### iter 2###  Current_Objvalue: 26.13, Best_Objvalue: 26.13
#    best_move: (8, 9), Objvalue: 17.930000000000003 => Best Improving => Admissible
#
#
# ### iter 3###  Current_Objvalue: 17.930000000000003, Best_Objvalue: 17.930000000000003
#    best_move: (3, 4), Objvalue: 14.960000000000003 => Best Improving => Admissible
#
#
# ### iter 4###  Current_Objvalue: 14.960000000000003, Best_Objvalue: 14.960000000000003
#    best_move: (4, 5), Objvalue: 14.200000000000003 => Best Improving => Admissible
#
#
# ### iter 5###  Current_Objvalue: 14.200000000000003, Best_Objvalue: 14.200000000000003
#    best_move: (6, 7), Objvalue: 13.830000000000002 => Best Improving => Admissible
#
#
# ### iter 6###  Current_Objvalue: 13.830000000000002, Best_Objvalue: 13.830000000000002
#    best_move: (1, 8), Objvalue: 13.530000000000001 => Best Improving => Admissible
#
#
# ### iter 7###  Current_Objvalue: 13.530000000000001, Best_Objvalue: 13.530000000000001
#    best_move: (4, 8), Objvalue: 13.370000000000001 => Best Improving => Admissible
#
#
# ### iter 8###  Current_Objvalue: 13.370000000000001, Best_Objvalue: 13.370000000000001
#    best_move: (7, 9), Objvalue: 13.260000000000002 => Best Improving => Admissible
#
#
# ### iter 9###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.260000000000002
#    best_move: (5, 10), Objvalue: 13.240000000000002 => Best Improving => Admissible
#
#
# ### iter 10###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 0## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 11###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 12###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 2## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 13###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 3## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 14###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 4## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 15###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 5## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 16###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 6## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 17###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 7## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 18###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 8## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 19###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 9## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 20###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 10## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 21###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 11## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 22###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 12## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 23###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 13## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 24###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 14## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 25###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 15## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 26###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 16## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 27###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 17## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 28###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 18## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 29###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 19## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 30###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 20## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 31###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 21## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 32###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 22## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 33###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 23## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 34###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 24## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 35###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 25## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 36###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 26## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 37###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 27## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 38###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 28## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 39###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 29## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 40###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 30## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 41###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 31## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 42###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 32## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 43###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 33## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 44###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 34## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 45###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 35## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 46###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 36## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 47###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 37## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 48###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 38## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 49###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 39## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 50###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 40## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 51###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 41## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 52###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 42## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 53###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 43## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 54###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 44## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 55###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 45## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 56###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 46## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 57###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 47## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 58###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 48## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 59###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 49## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 60###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 50## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 61###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 51## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 62###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 52## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 63###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 53## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 64###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 54## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 65###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 55## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 66###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 56## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 67###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 57## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 68###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 58## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 69###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 59## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 70###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 60## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 71###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 61## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 72###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 62## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 73###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 63## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 74###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 64## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 75###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 65## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 76###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 66## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 77###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 67## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 78###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 68## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 79###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 69## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 80###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 70## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 81###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 71## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 82###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 72## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 83###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 73## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 84###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 74## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 85###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 75## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 86###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 76## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 87###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 77## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 88###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 78## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 89###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 79## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 90###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 80## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 91###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 81## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 92###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 82## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 93###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 83## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 94###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 84## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 95###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 85## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 96###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 86## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 97###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 87## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 98###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 88## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 99###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 89## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 100###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 90## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 101###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 91## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
#
#
# ### iter 102###  Current_Objvalue: 13.280000000000001, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.280000000000001 => Tabu => Inadmissible
#    ##Termination: 92## best_move: (2, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 103###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    best_move: (1, 2), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (2, 3), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    best_move: (5, 10), Objvalue: 13.320000000000004 => Tabu => Inadmissible
#    ##Termination: 93## best_move: (1, 3), Objvalue: 13.320000000000004 => Least non-improving => Admissible
#
#
# ### iter 104###  Current_Objvalue: 13.320000000000004, Best_Objvalue: 13.240000000000002
#    ##Termination: 94## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 105###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 95## best_move: (5, 10), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 106###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    ##Termination: 96## best_move: (2, 3), Objvalue: 13.240000000000002 => Least non-improving => Admissible
#
#
# ### iter 107###  Current_Objvalue: 13.240000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (2, 3), Objvalue: 13.240000000000002 => Tabu => Inadmissible
#    ##Termination: 97## best_move: (1, 3), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 108###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 98## best_move: (1, 2), Objvalue: 13.260000000000002 => Least non-improving => Admissible
#
#
# ### iter 109###  Current_Objvalue: 13.260000000000002, Best_Objvalue: 13.240000000000002
#    best_move: (1, 3), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    best_move: (1, 2), Objvalue: 13.260000000000002 => Tabu => Inadmissible
#    ##Termination: 99## best_move: (5, 10), Objvalue: 13.280000000000001 => Least non-improving => Admissible
# ##################################################
# Performed iterations: 110
# Best found Solution: [3, 2, 1, 4, 8, 10, 5, 9, 7, 6] , Objvalue: 13.240000000000002

# %% [markdown]
# ## Második teszt:

# %% [markdown]
# Az adatunk az alábbi:

# %%
pd.read_excel('Instance_20.xlsx', names=['Job', 'weight', "processing_time", "due_date"], index_col=0)
# Out:
#      weight  processing_time  due_date
# Job
# 1       0.5              0.5         8
# 2       0.8              3.6         6
# 3       0.6              2.8         5
# 4       0.4              1.9        12
# 5       0.4              1.0        10
# 6       0.1              1.8        11
# 7       0.2              2.6         6
# 8       0.5              4.7        18
# 9       0.3              1.8         8
# 10      0.6              1.6        14
# 11      0.5              0.2         6
# 12      0.8              0.4        30
# 13      0.6              2.2        22
# 14      0.4              1.2         6
# 15      0.4              0.1        38
# 16      0.1              2.0        16
# 17      0.2              2.9        10
# 18      0.5              0.1        12
# 19      0.3              2.5        20
# 20      0.6              0.9        15

# %% [markdown]
# Ekkor a teszt:

# %%
test = TS(Path="Instance_20.xlsx", seed = 2012, tabu_tenure=3)
# Out:
# ##############################
#
# Short-term memory TS with Tabu Tenure: 3
# Initial Solution: [17, 14, 19, 18, 13, 20, 3, 2, 8, 6, 5, 15, 9, 1, 10, 11, 7, 12, 16, 4], Initial Objvalue: 70.75
#
# ##############################
#
#
# ### iter 1###  Current_Objvalue: 70.75, Best_Objvalue: 70.75
#    best_move: (11, 17), Objvalue: 53.120000000000005 => Best Improving => Admissible
#
#
# ### iter 2###  Current_Objvalue: 53.120000000000005, Best_Objvalue: 53.120000000000005
#    best_move: (1, 19), Objvalue: 41.94000000000002 => Best Improving => Admissible
#
#
# ### iter 3###  Current_Objvalue: 41.94000000000002, Best_Objvalue: 41.94000000000002
#    best_move: (4, 8), Objvalue: 34.90000000000001 => Best Improving => Admissible
#
#
# ### iter 4###  Current_Objvalue: 34.90000000000001, Best_Objvalue: 34.90000000000001
#    best_move: (10, 13), Objvalue: 28.36 => Best Improving => Admissible
#
#
# ### iter 5###  Current_Objvalue: 28.36, Best_Objvalue: 28.36
#    best_move: (2, 10), Objvalue: 25.639999999999997 => Best Improving => Admissible
#
#
# ### iter 6###  Current_Objvalue: 25.639999999999997, Best_Objvalue: 25.639999999999997
#    best_move: (5, 20), Objvalue: 23.869999999999997 => Best Improving => Admissible
#
#
# ### iter 7###  Current_Objvalue: 23.869999999999997, Best_Objvalue: 23.869999999999997
#    best_move: (8, 17), Objvalue: 22.400000000000002 => Best Improving => Admissible
#
#
# ### iter 8###  Current_Objvalue: 22.400000000000002, Best_Objvalue: 22.400000000000002
#    best_move: (3, 18), Objvalue: 21.6 => Best Improving => Admissible
#
#
# ### iter 9###  Current_Objvalue: 21.6, Best_Objvalue: 21.6
#    best_move: (6, 9), Objvalue: 21.040000000000003 => Best Improving => Admissible
#
#
# ### iter 10###  Current_Objvalue: 21.040000000000003, Best_Objvalue: 21.040000000000003
#    best_move: (9, 10), Objvalue: 20.490000000000002 => Best Improving => Admissible
#
#
# ### iter 11###  Current_Objvalue: 20.490000000000002, Best_Objvalue: 20.490000000000002
#    best_move: (16, 17), Objvalue: 20.38 => Best Improving => Admissible
#
#
# ### iter 12###  Current_Objvalue: 20.38, Best_Objvalue: 20.38
#    best_move: (9, 18), Objvalue: 20.349999999999998 => Best Improving => Admissible
#
#
# ### iter 13###  Current_Objvalue: 20.349999999999998, Best_Objvalue: 20.349999999999998
#    best_move: (1, 2), Objvalue: 20.34 => Best Improving => Admissible
#
#
# ### iter 14###  Current_Objvalue: 20.34, Best_Objvalue: 20.34
#    best_move: (3, 14), Objvalue: 19.86 => Best Improving => Admissible
#
#
# ### iter 15###  Current_Objvalue: 19.86, Best_Objvalue: 19.86
#    best_move: (6, 15), Objvalue: 19.85000000000001 => Best Improving => Admissible
#
#
# ### iter 16###  Current_Objvalue: 19.85000000000001, Best_Objvalue: 19.85000000000001
#    ##Termination: 0## best_move: (3, 11), Objvalue: 19.85000000000001 => Least non-improving => Admissible
#
#
# ### iter 17###  Current_Objvalue: 19.85000000000001, Best_Objvalue: 19.85000000000001
#    best_move: (3, 11), Objvalue: 19.85000000000001 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (15, 19), Objvalue: 19.85000000000001 => Least non-improving => Admissible
#
#
# ### iter 18###  Current_Objvalue: 19.85000000000001, Best_Objvalue: 19.85000000000001
#    best_move: (13, 15), Objvalue: 19.790000000000006 => Best Improving => Admissible
#
#
# ### iter 19###  Current_Objvalue: 19.790000000000006, Best_Objvalue: 19.790000000000006
#    best_move: (8, 15), Objvalue: 19.740000000000006 => Best Improving => Admissible
#
#
# ### iter 20###  Current_Objvalue: 19.740000000000006, Best_Objvalue: 19.740000000000006
#    best_move: (7, 15), Objvalue: 19.720000000000006 => Best Improving => Admissible
#
#
# ### iter 21###  Current_Objvalue: 19.720000000000006, Best_Objvalue: 19.720000000000006
#    best_move: (6, 15), Objvalue: 19.680000000000007 => Best Improving => Admissible
#
#
# ### iter 22###  Current_Objvalue: 19.680000000000007, Best_Objvalue: 19.680000000000007
#    best_move: (8, 19), Objvalue: 19.22 => Best Improving => Admissible
#
#
# ### iter 23###  Current_Objvalue: 19.22, Best_Objvalue: 19.22
#    best_move: (8, 15), Objvalue: 19.17000000000001 => Best Improving => Admissible
#
#
# ### iter 24###  Current_Objvalue: 19.17000000000001, Best_Objvalue: 19.17000000000001
#    best_move: (13, 15), Objvalue: 19.110000000000007 => Best Improving => Admissible
#
#
# ### iter 25###  Current_Objvalue: 19.110000000000007, Best_Objvalue: 19.110000000000007
#    best_move: (15, 19), Objvalue: 19.080000000000005 => Best Improving => Admissible
#
#
# ### iter 26###  Current_Objvalue: 19.080000000000005, Best_Objvalue: 19.080000000000005
#    best_move: (7, 15), Objvalue: 19.060000000000006 => Best Improving => Admissible
#
#
# ### iter 27###  Current_Objvalue: 19.060000000000006, Best_Objvalue: 19.060000000000006
#    best_move: (6, 15), Objvalue: 19.050000000000004 => Best Improving => Admissible
#
#
# ### iter 28###  Current_Objvalue: 19.050000000000004, Best_Objvalue: 19.050000000000004
#    ##Termination: 0## best_move: (3, 11), Objvalue: 19.050000000000004 => Least non-improving => Admissible
#
#
# ### iter 29###  Current_Objvalue: 19.050000000000004, Best_Objvalue: 19.050000000000004
#    best_move: (3, 11), Objvalue: 19.050000000000004 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (12, 15), Objvalue: 19.050000000000004 => Least non-improving => Admissible
#
#
# ### iter 30###  Current_Objvalue: 19.050000000000004, Best_Objvalue: 19.050000000000004
#    best_move: (15, 17), Objvalue: 19.030000000000005 => Best Improving => Admissible
#
#
# ### iter 31###  Current_Objvalue: 19.030000000000005, Best_Objvalue: 19.030000000000005
#    best_move: (15, 16), Objvalue: 19.020000000000007 => Best Improving => Admissible
#
#
# ### iter 32###  Current_Objvalue: 19.020000000000007, Best_Objvalue: 19.020000000000007
#    ##Termination: 0## best_move: (3, 11), Objvalue: 19.020000000000007 => Least non-improving => Admissible
#
#
# ### iter 33###  Current_Objvalue: 19.020000000000007, Best_Objvalue: 19.020000000000007
#    best_move: (3, 11), Objvalue: 19.020000000000007 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.020000000000007 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (6, 15), Objvalue: 19.05 => Least non-improving => Admissible
#
#
# ### iter 34###  Current_Objvalue: 19.05, Best_Objvalue: 19.020000000000007
#    best_move: (6, 15), Objvalue: 19.05 => Tabu => Inadmissible
#    ##Termination: 2## best_move: (6, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 35###  Current_Objvalue: 19.03, Best_Objvalue: 19.020000000000007
#    best_move: (3, 11), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 3## best_move: (12, 15), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 36###  Current_Objvalue: 19.03, Best_Objvalue: 19.020000000000007
#    best_move: (15, 17), Objvalue: 19.01 => Best Improving => Admissible
#
#
# ### iter 37###  Current_Objvalue: 19.01, Best_Objvalue: 19.01
#    best_move: (6, 15), Objvalue: 19.0 => Best Improving => Admissible
#
#
# ### iter 38###  Current_Objvalue: 19.0, Best_Objvalue: 19.0
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Best Improving => Admissible
#
#
# ### iter 39###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 0## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 40###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 41###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 2## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 42###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 3## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 43###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 4## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 44###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 5## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 45###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 6## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 46###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 7## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 47###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 8## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 48###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 9## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 49###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 10## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 50###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 11## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 51###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 12## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 52###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 13## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 53###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 14## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 54###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 15## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 55###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 16## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 56###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 17## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 57###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 18## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 58###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 19## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 59###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 20## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 60###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 21## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 61###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 22## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 62###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 23## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 63###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 24## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 64###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 25## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 65###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 26## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 66###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 27## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 67###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 28## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 68###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 29## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 69###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 30## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 70###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 31## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 71###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 32## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 72###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 33## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 73###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 34## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 74###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 35## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 75###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 36## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 76###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 37## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 77###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 38## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 78###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 39## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 79###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 40## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 80###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 41## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 81###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 42## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 82###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 43## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 83###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 44## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 84###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 45## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 85###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 46## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 86###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 47## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 87###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 48## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 88###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 49## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 89###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 50## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 90###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 51## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 91###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 52## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 92###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 53## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 93###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 54## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 94###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 55## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 95###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 56## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 96###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 57## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 97###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 58## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 98###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 59## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 99###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 60## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 100###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 61## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 101###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 62## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 102###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 63## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 103###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 64## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 104###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 65## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 105###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 66## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 106###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 67## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 107###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 68## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 108###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 69## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 109###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 70## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 110###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 71## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 111###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 72## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 112###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 73## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 113###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 74## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 114###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 75## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 115###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 76## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 116###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 77## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 117###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 78## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 118###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 79## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 119###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 80## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 120###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 81## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 121###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 82## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 122###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 83## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 123###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 84## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 124###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 85## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 125###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 86## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 126###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 87## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 127###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 88## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 128###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 89## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 129###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 90## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 130###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 91## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 131###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (6, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 92## best_move: (3, 11), Objvalue: 19.03 => Least non-improving => Admissible
#
#
# ### iter 132###  Current_Objvalue: 19.03, Best_Objvalue: 18.990000000000002
#    best_move: (6, 15), Objvalue: 19.03 => Tabu => Inadmissible
#    ##Termination: 93## best_move: (6, 16), Objvalue: 19.01 => Least non-improving => Admissible
#
#
# ### iter 133###  Current_Objvalue: 19.01, Best_Objvalue: 18.990000000000002
#    ##Termination: 94## best_move: (6, 15), Objvalue: 19.0 => Least non-improving => Admissible
#
#
# ### iter 134###  Current_Objvalue: 19.0, Best_Objvalue: 18.990000000000002
#    ##Termination: 95## best_move: (15, 16), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 135###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    ##Termination: 96## best_move: (3, 11), Objvalue: 18.990000000000002 => Least non-improving => Admissible
#
#
# ### iter 136###  Current_Objvalue: 18.990000000000002, Best_Objvalue: 18.990000000000002
#    best_move: (3, 11), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 18.990000000000002 => Tabu => Inadmissible
#    ##Termination: 97## best_move: (6, 16), Objvalue: 19.010000000000005 => Least non-improving => Admissible
#
#
# ### iter 137###  Current_Objvalue: 19.010000000000005, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (15, 16), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.010000000000005 => Tabu => Inadmissible
#    ##Termination: 98## best_move: (6, 15), Objvalue: 19.020000000000003 => Least non-improving => Admissible
#
#
# ### iter 138###  Current_Objvalue: 19.020000000000003, Best_Objvalue: 18.990000000000002
#    best_move: (6, 16), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (6, 15), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    best_move: (3, 11), Objvalue: 19.020000000000003 => Tabu => Inadmissible
#    ##Termination: 99## best_move: (15, 16), Objvalue: 19.03 => Least non-improving => Admissible
# ##################################################
# Performed iterations: 139
# Best found Solution: [3, 11, 2, 14, 1, 5, 9, 18, 4, 10, 20, 8, 13, 19, 7, 12, 17, 6, 16, 15] , Objvalue: 18.990000000000002

# %% [markdown]
# ## Harmadik teszt:

# %% [markdown]
# Az adatunk az alábbi:

# %%
pd.read_excel('Instance_30.xlsx', names=['Job', 'weight', "processing_time", "due_date"], index_col=0)
# Out:
#      weight  processing_time  due_date
# Job
# 1       0.5                6        29
# 2       0.9                1        38
# 3       0.0                2        28
# 4       0.3                6        35
# 5       0.6                5        43
# 6       0.3                4        44
# 7       0.9                6        26
# 8       0.4                1        18
# 9       0.2                2        48
# 10      0.4                4        37
# 11      1.0                1        26
# 12      0.1                4        36
# 13      0.4                6        24
# 14      0.8                3        45
# 15      0.1                4        41
# 16      1.0                1        18
# 17      0.1                3        46
# 18      0.4                4        36
# 19      0.7                8        20
# 20      1.0                8        18
# 21      0.2                2        25
# 22      0.1                2        34
# 23      0.0                2        36
# 24      0.6                4        42
# 25      0.1                5        29
# 26      0.9                6        26
# 27      0.7                3        33
# 28      0.6                1        24
# 29      0.4                1        25
# 30      0.9                4        26

# %% [markdown]
# Ekkor a teszt:

# %%
test = TS(Path="Instance_30.xlsx", seed = 2012, tabu_tenure=3)
# Out:
# ##############################
#
# Short-term memory TS with Tabu Tenure: 3
# Initial Solution: [13, 2, 25, 24, 21, 22, 23, 6, 28, 27, 3, 5, 8, 18, 15, 14, 9, 30, 29, 26, 10, 20, 17, 1, 19, 11, 7, 12, 16, 4], Initial Objvalue: 479.4
#
# ##############################
#
#
# ### iter 1###  Current_Objvalue: 479.4, Best_Objvalue: 479.4
#    best_move: (16, 25), Objvalue: 364.99999999999994 => Best Improving => Admissible
#
#
# ### iter 2###  Current_Objvalue: 364.99999999999994, Best_Objvalue: 364.99999999999994
#    best_move: (11, 23), Objvalue: 297.19999999999993 => Best Improving => Admissible
#
#
# ### iter 3###  Current_Objvalue: 297.19999999999993, Best_Objvalue: 297.19999999999993
#    best_move: (6, 7), Objvalue: 263.40000000000003 => Best Improving => Admissible
#
#
# ### iter 4###  Current_Objvalue: 263.40000000000003, Best_Objvalue: 263.40000000000003
#    best_move: (13, 20), Objvalue: 239.39999999999998 => Best Improving => Admissible
#
#
# ### iter 5###  Current_Objvalue: 239.39999999999998, Best_Objvalue: 239.39999999999998
#    best_move: (24, 30), Objvalue: 221.39999999999998 => Best Improving => Admissible
#
#
# ### iter 6###  Current_Objvalue: 221.39999999999998, Best_Objvalue: 221.39999999999998
#    best_move: (22, 29), Objvalue: 208.39999999999998 => Best Improving => Admissible
#
#
# ### iter 7###  Current_Objvalue: 208.39999999999998, Best_Objvalue: 208.39999999999998
#    best_move: (3, 26), Objvalue: 194.49999999999997 => Best Improving => Admissible
#
#
# ### iter 8###  Current_Objvalue: 194.49999999999997, Best_Objvalue: 194.49999999999997
#    best_move: (6, 15), Objvalue: 185.29999999999998 => Best Improving => Admissible
#
#
# ### iter 9###  Current_Objvalue: 185.29999999999998, Best_Objvalue: 185.29999999999998
#    best_move: (8, 21), Objvalue: 177.99999999999997 => Best Improving => Admissible
#
#
# ### iter 10###  Current_Objvalue: 177.99999999999997, Best_Objvalue: 177.99999999999997
#    best_move: (3, 19), Objvalue: 171.70000000000002 => Best Improving => Admissible
#
#
# ### iter 11###  Current_Objvalue: 171.70000000000002, Best_Objvalue: 171.70000000000002
#    best_move: (3, 4), Objvalue: 167.8 => Best Improving => Admissible
#
#
# ### iter 12###  Current_Objvalue: 167.8, Best_Objvalue: 167.8
#    best_move: (6, 24), Objvalue: 165.10000000000002 => Best Improving => Admissible
#
#
# ### iter 13###  Current_Objvalue: 165.10000000000002, Best_Objvalue: 165.10000000000002
#    best_move: (26, 27), Objvalue: 162.4 => Best Improving => Admissible
#
#
# ### iter 14###  Current_Objvalue: 162.4, Best_Objvalue: 162.4
#    best_move: (14, 18), Objvalue: 159.8 => Best Improving => Admissible
#
#
# ### iter 15###  Current_Objvalue: 159.8, Best_Objvalue: 159.8
#    best_move: (1, 22), Objvalue: 157.39999999999998 => Best Improving => Admissible
#
#
# ### iter 16###  Current_Objvalue: 157.39999999999998, Best_Objvalue: 157.39999999999998
#    best_move: (6, 10), Objvalue: 155.6 => Best Improving => Admissible
#
#
# ### iter 17###  Current_Objvalue: 155.6, Best_Objvalue: 155.6
#    best_move: (5, 18), Objvalue: 153.99999999999997 => Best Improving => Admissible
#
#
# ### iter 18###  Current_Objvalue: 153.99999999999997, Best_Objvalue: 153.99999999999997
#    best_move: (14, 24), Objvalue: 152.99999999999997 => Best Improving => Admissible
#
#
# ### iter 19###  Current_Objvalue: 152.99999999999997, Best_Objvalue: 152.99999999999997
#    best_move: (4, 17), Objvalue: 152.59999999999997 => Best Improving => Admissible
#
#
# ### iter 20###  Current_Objvalue: 152.59999999999997, Best_Objvalue: 152.59999999999997
#    best_move: (12, 23), Objvalue: 152.2 => Best Improving => Admissible
#
#
# ### iter 21###  Current_Objvalue: 152.2, Best_Objvalue: 152.2
#    best_move: (23, 25), Objvalue: 151.99999999999997 => Best Improving => Admissible
#
#
# ### iter 22###  Current_Objvalue: 151.99999999999997, Best_Objvalue: 151.99999999999997
#    best_move: (1, 19), Objvalue: 151.79999999999998 => Best Improving => Admissible
#
#
# ### iter 23###  Current_Objvalue: 151.79999999999998, Best_Objvalue: 151.79999999999998
#    ##Termination: 0## best_move: (2, 8), Objvalue: 151.79999999999998 => Least non-improving => Admissible
#
#
# ### iter 24###  Current_Objvalue: 151.79999999999998, Best_Objvalue: 151.79999999999998
#    ##Termination: 1## best_move: (2, 7), Objvalue: 151.79999999999998 => Least non-improving => Admissible
#
#
# ### iter 25###  Current_Objvalue: 151.79999999999998, Best_Objvalue: 151.79999999999998
#    best_move: (2, 7), Objvalue: 151.79999999999998 => Tabu => Inadmissible
#    ##Termination: 2## best_move: (2, 11), Objvalue: 151.79999999999998 => Least non-improving => Admissible
#
#
# ### iter 26###  Current_Objvalue: 151.79999999999998, Best_Objvalue: 151.79999999999998
#    best_move: (2, 7), Objvalue: 151.79999999999998 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 151.79999999999998 => Tabu => Inadmissible
#    ##Termination: 3## best_move: (2, 28), Objvalue: 151.79999999999998 => Least non-improving => Admissible
#
#
# ### iter 27###  Current_Objvalue: 151.79999999999998, Best_Objvalue: 151.79999999999998
#    best_move: (2, 26), Objvalue: 150.89999999999998 => Best Improving => Admissible
#
#
# ### iter 28###  Current_Objvalue: 150.89999999999998, Best_Objvalue: 150.89999999999998
#    ##Termination: 0## best_move: (2, 27), Objvalue: 150.89999999999998 => Least non-improving => Admissible
#
#
# ### iter 29###  Current_Objvalue: 150.89999999999998, Best_Objvalue: 150.89999999999998
#    best_move: (2, 18), Objvalue: 150.49999999999997 => Best Improving => Admissible
#
#
# ### iter 30###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 0## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 31###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 1## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 32###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 2## best_move: (7, 26), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 33###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 26), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 3## best_move: (7, 30), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 34###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 4## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 35###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 5## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 36###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 6## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 37###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 7## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 38###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 8## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 39###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 9## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 40###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 10## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 41###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 11## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 42###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 12## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 43###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 13## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 44###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 14## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 45###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 15## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 46###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 16## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 47###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 17## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 48###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 18## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 49###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 19## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 50###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 20## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 51###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 21## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 52###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 22## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 53###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 23## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 54###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 24## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 55###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 25## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 56###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 26## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 57###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 27## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 58###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 28## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 59###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 29## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 60###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 30## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 61###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 31## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 62###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 32## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 63###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 33## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 64###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 34## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 65###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 35## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 66###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 36## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 67###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 37## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 68###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 38## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 69###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 39## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 70###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 40## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 71###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 41## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 72###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 42## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 73###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 43## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 74###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 44## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 75###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 45## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 76###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 46## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 77###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 47## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 78###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 48## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 79###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 49## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 80###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 50## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 81###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 51## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 82###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 52## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 83###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 53## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 84###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 54## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 85###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 55## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 86###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 56## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 87###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 57## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 88###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 58## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 89###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 59## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 90###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 60## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 91###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 61## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 92###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 62## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 93###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 63## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 94###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 64## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 95###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 65## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 96###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 66## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 97###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 67## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 98###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 68## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 99###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 69## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 100###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 70## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 101###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 71## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 102###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 72## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 103###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 73## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 104###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 74## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 105###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 75## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 106###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 76## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 107###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 77## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 108###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 78## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 109###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 79## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 110###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 80## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 111###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 81## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 112###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 82## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 113###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 83## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 114###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 84## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 115###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 85## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 116###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 86## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 117###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 87## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 118###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 88## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 119###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 89## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 120###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 90## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 121###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 91## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 122###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 92## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 123###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 93## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 124###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 94## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 125###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 95## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 126###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    ##Termination: 96## best_move: (3, 23), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 127###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 97## best_move: (7, 8), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 128###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 98## best_move: (7, 11), Objvalue: 150.49999999999997 => Least non-improving => Admissible
#
#
# ### iter 129###  Current_Objvalue: 150.49999999999997, Best_Objvalue: 150.49999999999997
#    best_move: (3, 23), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 8), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    best_move: (7, 11), Objvalue: 150.49999999999997 => Tabu => Inadmissible
#    ##Termination: 99## best_move: (7, 16), Objvalue: 150.49999999999997 => Least non-improving => Admissible
# ##################################################
# Performed iterations: 130
# Best found Solution: [20, 8, 16, 30, 7, 29, 28, 11, 26, 27, 18, 2, 21, 24, 14, 5, 9, 10, 19, 1, 6, 13, 4, 22, 17, 12, 15, 25, 23, 3] , Objvalue: 150.49999999999997
